# %%
import pandas as pd

# %%
import matplotlib

# %%
df = pd.read_csv('Section_3.csv')

# %%
times = pd.to_datetime(df['Review_Date'])

# %%
vals = times.dt.day_name().value_counts()

# %%
times.dt.day_name().value_counts().plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
